# %%
import pandas as pd

# %%
#Series

import pandas as pd
data = [1, 2, 3, 4, 5]
series = pd.Series(data)
print("Series \n", series)
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
## create a  series from dictionary
data = {'a': 1, 'b': 2, 'c': 3}
series_dict = pd.Series(data)
print("Series from dictionary \n", series_dict)
# Out:
# Series from dictionary
#  a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10, 20, 30]
index = ['a', 'b', 'c']
series_index = pd.Series(data, index=index)
print("Series with custom index \n", series_index)
# Out:
# Series with custom index
#  a    10
# b    20
# c    30
# dtype: int64

# %%
## DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df= pd.DataFrame(data)
print("DataFrame \n", df)
print(type(df))
# Out:
# DataFrame
#        Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# <class 'pandas.core.frame.DataFrame'>

# %%
df=pd.read_csv('sales_data.csv')
df.head(5)
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
## Accessing Data in DataFrame
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.loc[0]
# Out:
# Name       Alice
# Age           25
# City    New York
# Name: 0, dtype: object

# %%
df.iloc[0][1]
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_21016\2309508539.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][1]
# 25

# %%
# Accessing a specific column
df['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
df.at[1,'Age']
# Out:
# 30

# %%
df.at[2,'Name']
# Out:
# 'Charlie'

# %%
## Accessing a specific element using iat
df.iat[2,2]
# Out:
# 'Chicago'

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
#data Manipulation with DataFrame
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
#Adding a colum
df['Salary']=[50000, 60000, 55000]
df
# Out:
#       Name  Age         City  Salary
# 0    Alice   25     New York   50000
# 1      Bob   30  Los Angeles   60000
# 2  Charlie   35      Chicago   55000

# %%
# Remove a colum
df.drop('Salary', axis=1, inplace=True)

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
# Add age to the column
df['Age'] = df['Age'] + 5   
df
# Out:
#       Name  Age         City
# 0    Alice   35     New York
# 1      Bob   40  Los Angeles
# 2  Charlie   45      Chicago

# %%
df.drop(0, axis=0, inplace=True)

# %%
df
# Out:
#       Name  Age         City
# 1      Bob   40  Los Angeles
# 2  Charlie   45      Chicago
