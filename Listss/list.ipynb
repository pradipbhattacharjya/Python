# %%
lst =[]
print(type(lst))
# Out:
# <class 'list'>

# %%
names=["Krish","Jack","Jill",1,2,3,4,5]
print(names)
# Out:
# ['Krish', 'Jack', 'Jill', 1, 2, 3, 4, 5]

# %%
mixed_list=[1,"Krish",2.5,True]
print(mixed_list)
# Out:
# [1, 'Krish', 2.5, True]
