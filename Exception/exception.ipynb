# %%
#Exception try, except block
try:
    a=b
except:
    print("The variable has not been assigned")
# Out:
# The variable has not been assigned

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result = 1 / 0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator greater than 0")
# Out:
# division by zero
# Please enter the denominator greater than 0

# %%
try:
    result = 1 / 2
    a = b
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator greater than 0")
except NameError as ex1:
    print(ex1)
    print("Main excepation got caught here")
# Out:
# name 'b' is not defined
# Main excepation got caught here

# %%
try:
    number = int(input("Enter a number: "))
    result = 10 / number    
except ValueError:
    print("Please enter a valid integer.")
except ZeroDivisionError :
    print("Please enter a non-zero integer.")
except Exception as ex:
    print(f"An unexpected error occurred: {ex}")
# Out:
# Please enter a valid integer.

# %%
#try,except, else block
try:
    number = int(input("Enter a number: "))
    result = 10 / number
except ValueError:
    print("Please enter a valid integer.")
except ZeroDivisionError :
    print("Please enter a non-zero integer.")
except Exception as ex:
    print(f"An unexpected error occurred: {ex}")
else:
    print(f"The result is: {result}")
# Out:
# The result is: 0.8333333333333334

# %%
## try, except, else, finally block
try:
    number = int(input("Enter a number: "))
    result = 10 / number
except ValueError:
    print("Please enter a valid integer.")
except ZeroDivisionError:
    print("Please enter a non-zero integer.")
except Exception as ex:
    print(f"An unexpected error occurred: {ex}")
else:
    print(f"The result is: {result}")
finally:
    print("Execution of the try-except block is complete.")
# Out:
# Please enter a non-zero integer.
# Execution of the try-except block is complete.

# %%
## File handling and Exception handling

try:
    file=open("example1.txt",'r')
    content=file.read()
    print(content)

except FileNotFoundError:
    print("The filr does not exists")

except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print("file close")
# Out:
# file close
