# %%
import pandas as pd
from pandas import DataFrame

# %%
toyota_data = pd.read_csv('toyota_sales_data.csv')

# %%
toyota_data
# Out:
#       sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0           1           16  2024-11-18    Tundra     44496.88            0.05
# 1           2           11  2024-11-08    Tacoma     34824.72             NaN
# 2           3            5  2024-11-03   Corolla     20275.08             NaN
# 3           4           20  2024-11-06   Corolla     20068.93             NaN
# 4           5            1  2024-11-26    Tundra     49811.99            0.03
# ...       ...          ...         ...       ...          ...             ...
# 4995     4996            1  2024-11-06   Corolla     21484.83            0.05
# 4996     4997            8  2024-11-11     Camry     26519.24            0.05
# 4997     4998           18  2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10  2024-11-21   Corolla     22654.59             NaN
# 4999     5000           13  2024-11-21    Tundra     44525.85             NaN
#
#      sale_status
# ...

# %%
toyota_data.shape
# Out:
# (5000, 7)

# %%
chunk_size = 100

# %%
toyota_chunk_reader = pd.read_csv(
    'toyota_sales_data.csv',
    chunksize=chunk_size
                  )

# %%
type(toyota_chunk_reader)
# Out:
# pandas.io.parsers.readers.TextFileReader

# %%
type(toyota_data)
# Out:
# pandas.core.frame.DataFrame

# %%
for toyota_chunk in toyota_chunk_reader:
    print(toyota_chunk)
# Out:
#     sale_id  sale_rep_id   sale_date   car_model  sale_amount  commission_pct  \
# 0         1           16  2024-11-18      Tundra     44496.88            0.05
# 1         2           11  2024-11-08      Tacoma     34824.72             NaN
# 2         3            5  2024-11-03     Corolla     20275.08             NaN
# 3         4           20  2024-11-06     Corolla     20068.93             NaN
# 4         5            1  2024-11-26      Tundra     49811.99            0.03
# ..      ...          ...         ...         ...          ...             ...
# 95       96           16  2024-11-17  Highlander     44498.46            0.03
# 96       97            6  2024-11-23  Highlander     41994.79             NaN
# 97       98            1  2024-11-07      Tacoma     31378.09            0.02
# 98       99            1  2024-11-04      Tundra     39879.41            0.02
# 99      100           16  2024-11-20       Camry     25962.56            0.02
#
#    sale_status
# 0    Completed
# ...

# %%
for toyota_chunk in toyota_chunk_reader:
    print(toyota_chunk.head())

# %% [markdown]
# How to Apply Transformations on DataFrame
