# %%
import pandas as pd

# %%
#Load the Toyota sales dataset
toyota_data = pd.read_csv('toyota_sales_data_no_header.csv')

# %%
toyota_data.head()
# Out:
#    1  16  2024-11-18   Tundra  44496.88  0.05  Completed
# 0  2  11  2024-11-08   Tacoma  34824.72   NaN    Pending
# 1  3   5  2024-11-03  Corolla  20275.08   NaN  Completed
# 2  4  20  2024-11-06  Corolla  20068.93   NaN  Completed
# 3  5   1  2024-11-26   Tundra  49811.99  0.03  Completed
# 4  6  14  2024-11-28     RAV4  34346.20  0.03  Completed

# %%
toyota_data = pd.read_csv(
    "toyota_sales_data_no_header.csv",
    header=None,
    names=["sale_id","sale_rep_id","sale_date","car_model","sale_amount","commission_pct","sale_status"]
)

# %%
toyota_data
# Out:
#       sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0           1           16  2024-11-18    Tundra     44496.88            0.05
# 1           2           11  2024-11-08    Tacoma     34824.72             NaN
# 2           3            5  2024-11-03   Corolla     20275.08             NaN
# 3           4           20  2024-11-06   Corolla     20068.93             NaN
# 4           5            1  2024-11-26    Tundra     49811.99            0.03
# ...       ...          ...         ...       ...          ...             ...
# 4995     4996            1  2024-11-06   Corolla     21484.83            0.05
# 4996     4997            8  2024-11-11     Camry     26519.24            0.05
# 4997     4998           18  2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10  2024-11-21   Corolla     22654.59             NaN
# 4999     5000           13  2024-11-21    Tundra     44525.85             NaN
#
#      sale_status
# ...

# %%
toyota_data = pd.read_csv("toyota_sales_data.csv")

# %%
toyota_data.columns
# Out:
# Index(['sale_id', 'sale_rep_id', 'sale_date', 'car_model', 'sale_amount',
#        'commission_pct', 'sale_status'],
#       dtype='object')

# %%
toyota_data_renamed = toyota_data.rename(columns={"commission_pct":"commission_percentage"})

# %%
toyota_data_renamed
# Out:
#       sale_id  sale_rep_id   sale_date car_model  sale_amount  \
# 0           1           16  2024-11-18    Tundra     44496.88
# 1           2           11  2024-11-08    Tacoma     34824.72
# 2           3            5  2024-11-03   Corolla     20275.08
# 3           4           20  2024-11-06   Corolla     20068.93
# 4           5            1  2024-11-26    Tundra     49811.99
# ...       ...          ...         ...       ...          ...
# 4995     4996            1  2024-11-06   Corolla     21484.83
# 4996     4997            8  2024-11-11     Camry     26519.24
# 4997     4998           18  2024-11-06    Tacoma     30780.39
# 4998     4999           10  2024-11-21   Corolla     22654.59
# 4999     5000           13  2024-11-21    Tundra     44525.85
#
#       commission_percentage sale_status
# 0                      0.05   Completed
# 1                       NaN     Pending
# 2                       NaN   Completed
# 3                       NaN   Completed
# ...

# %%
toyota_data.columns
# Out:
# Index(['sale_id', 'sale_rep_id', 'sale_date', 'car_model', 'sale_amount',
#        'commission_pct', 'sale_status'],
#       dtype='object')

# %%
column_name_reordered = ['sale_id', 'sale_rep_id', 'sale_date', 'car_model', 'sale_amount',
       'commission_pct', 'sale_status'],

# %%
toyota_data_renamed = toyota_data[column_name_reordered]

# %%
toyota_data_renamed
# Out:
#       sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0           1           16  2024-11-18    Tundra     44496.88            0.05
# 1           2           11  2024-11-08    Tacoma     34824.72             NaN
# 2           3            5  2024-11-03   Corolla     20275.08             NaN
# 3           4           20  2024-11-06   Corolla     20068.93             NaN
# 4           5            1  2024-11-26    Tundra     49811.99            0.03
# ...       ...          ...         ...       ...          ...             ...
# 4995     4996            1  2024-11-06   Corolla     21484.83            0.05
# 4996     4997            8  2024-11-11     Camry     26519.24            0.05
# 4997     4998           18  2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10  2024-11-21   Corolla     22654.59             NaN
# 4999     5000           13  2024-11-21    Tundra     44525.85             NaN
#
#      sale_status
# ...

# %%
toyota_data_upper = toyota_data.rename(columns=str.upper)

# %%
toyota_data_upper
# Out:
#       SALE_ID  SALE_REP_ID   SALE_DATE CAR_MODEL  SALE_AMOUNT  COMMISSION_PCT  \
# 0           1           16  2024-11-18    Tundra     44496.88            0.05
# 1           2           11  2024-11-08    Tacoma     34824.72             NaN
# 2           3            5  2024-11-03   Corolla     20275.08             NaN
# 3           4           20  2024-11-06   Corolla     20068.93             NaN
# 4           5            1  2024-11-26    Tundra     49811.99            0.03
# ...       ...          ...         ...       ...          ...             ...
# 4995     4996            1  2024-11-06   Corolla     21484.83            0.05
# 4996     4997            8  2024-11-11     Camry     26519.24            0.05
# 4997     4998           18  2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10  2024-11-21   Corolla     22654.59             NaN
# 4999     5000           13  2024-11-21    Tundra     44525.85             NaN
#
#      SALE_STATUS
# ...
