# %%
import pandas as pd

# %%
toyota_data = pd.read_csv(
    "toyota_sales_data.csv",
    delimiter=","
)

# %%
toyota_data
# Out:
#       sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0           1           16  2024-11-18    Tundra     44496.88            0.05
# 1           2           11  2024-11-08    Tacoma     34824.72             NaN
# 2           3            5  2024-11-03   Corolla     20275.08             NaN
# 3           4           20  2024-11-06   Corolla     20068.93             NaN
# 4           5            1  2024-11-26    Tundra     49811.99            0.03
# ...       ...          ...         ...       ...          ...             ...
# 4995     4996            1  2024-11-06   Corolla     21484.83            0.05
# 4996     4997            8  2024-11-11     Camry     26519.24            0.05
# 4997     4998           18  2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10  2024-11-21   Corolla     22654.59             NaN
# 4999     5000           13  2024-11-21    Tundra     44525.85             NaN
#
#      sale_status
# ...

# %%
toyota_data.head()
# Out:
#    sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0        1           16  2024-11-18    Tundra     44496.88            0.05
# 1        2           11  2024-11-08    Tacoma     34824.72             NaN
# 2        3            5  2024-11-03   Corolla     20275.08             NaN
# 3        4           20  2024-11-06   Corolla     20068.93             NaN
# 4        5            1  2024-11-26    Tundra     49811.99            0.03
#
#   sale_status
# 0   Completed
# 1     Pending
# 2   Completed
# 3   Completed
# 4   Completed

# %%
toyota_data["commission_amount"] = (toyota_data["sale_amount"] * toyota_data["commission_pct"]).fillna(0).round(2)

# %%
toyota_data.head()
# Out:
#    sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0        1           16  2024-11-18    Tundra     44496.88            0.05
# 1        2           11  2024-11-08    Tacoma     34824.72             NaN
# 2        3            5  2024-11-03   Corolla     20275.08             NaN
# 3        4           20  2024-11-06   Corolla     20068.93             NaN
# 4        5            1  2024-11-26    Tundra     49811.99            0.03
#
#   sale_status  commission_amount
# 0   Completed            2224.84
# 1     Pending               0.00
# 2   Completed               0.00
# 3   Completed               0.00
# 4   Completed            1494.36

# %% [markdown]
# Export Processed Data From Pandas Dataframe

# %%
help(toyota_data.to_csv)
# Out:
# Help on method to_csv in module pandas.core.generic:
#
# to_csv(
#     path_or_buf: 'FilePath | WriteBuffer[bytes] | WriteBuffer[str] | None' = None,
#     *,
#     sep: 'str' = ',',
#     na_rep: 'str' = '',
#     float_format: 'str | Callable | None' = None,
#     columns: 'Sequence[Hashable] | None' = None,
#     header: 'bool_t | list[str]' = True,
#     index: 'bool_t' = True,
#     index_label: 'IndexLabel | None' = None,
#     mode: 'str' = 'w',
#     encoding: 'str | None' = None,
#     compression: 'CompressionOptions' = 'infer',
#     quoting: 'int | None' = None,
#     quotechar: 'str' = '"',
#     lineterminator: 'str | None' = None,
#     chunksize: 'int | None' = None,
#     date_format: 'str | None' = None,
#     doublequote: 'bool_t' = True,
#     escapechar: 'str | None' = None,
#     decimal: 'str' = '.',
#     errors: 'OpenFileErrors' = 'strict',
#     storage_options: 'StorageOptions | None' = None
# ...

# %%
toyota_data.to_csv('toyota_sales_with_commission.csv')

# %% [markdown]
# Overview of Pandas ans postgres  Database Integrating
