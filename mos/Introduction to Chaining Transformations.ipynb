# %%
import pandas as pd

# %%
#Load the Toyota sales dataset
toyota_sales_data = pd.read_csv("toyota_sales_data.csv")
sales_reps_data = pd.read_csv("sales_reps_data.csv")

# %%
toyota_sales_data.head()
# Out:
#    sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0        1           16  2024-11-18    Tundra     44496.88            0.05
# 1        2           11  2024-11-08    Tacoma     34824.72             NaN
# 2        3            5  2024-11-03   Corolla     20275.08             NaN
# 3        4           20  2024-11-06   Corolla     20068.93             NaN
# 4        5            1  2024-11-26    Tundra     49811.99            0.03
#
#   sale_status
# 0   Completed
# 1     Pending
# 2   Completed
# 3   Completed
# 4   Completed

# %%
sales_reps_data.head()
# Out:
#    rep_id first_name last_name                     email  phone_number  \
# 0       1    Anthony     Davis  anthony.davis@toyota.com         -5390
# 1       2     Edward     Smith   edward.smith@toyota.com        -10708
# 2       3       Paul     Jones     paul.jones@toyota.com         -2301
# 3       4     Robert     Lopez   robert.lopez@toyota.com         -8631
# 4       5     Steven    Wilson  steven.wilson@toyota.com         -6958
#
#   hire_date region  status
# 0   7/21/22  North  Active
# 1  12/24/19  North  Active
# 2    9/6/22   East  Active
# 3  11/21/20  South  Active
# 4   3/17/22   West  Active

# %%
completed_sales = toyota_sales_data[toyota_sales_data["sale_status"] == "Completed"]

# %%
completed_sales
# Out:
#       sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0           1           16  2024-11-18    Tundra     44496.88            0.05
# 2           3            5  2024-11-03   Corolla     20275.08             NaN
# 3           4           20  2024-11-06   Corolla     20068.93             NaN
# 4           5            1  2024-11-26    Tundra     49811.99            0.03
# 5           6           14  2024-11-28      RAV4     34346.20            0.03
# ...       ...          ...         ...       ...          ...             ...
# 4992     4993           10  2024-11-26    Tundra     47497.87            0.02
# 4993     4994            4  2024-11-07     Camry     26498.13            0.05
# 4995     4996            1  2024-11-06   Corolla     21484.83            0.05
# 4997     4998           18  2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10  2024-11-21   Corolla     22654.59             NaN
#
#      sale_status
# ...

# %%
completed_sales["commission_earned"] = completed_sales["sale_amount"] * completed_sales["commission_pct"]
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_13464\4124943139.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completed_sales["commission_earned"] = completed_sales["sale_amount"] * completed_sales["commission_pct"]

# %%
sales_with_commission = toyota_sales_data[toyota_sales_data["sale_status"] == "Completed"]\
    .assign(commission_earned = lambda x : round(x["sale_amount"] * x["commission_pct"],2))

# %%
sales_with_commission
# Out:
#       sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0           1           16  2024-11-18    Tundra     44496.88            0.05
# 2           3            5  2024-11-03   Corolla     20275.08             NaN
# 3           4           20  2024-11-06   Corolla     20068.93             NaN
# 4           5            1  2024-11-26    Tundra     49811.99            0.03
# 5           6           14  2024-11-28      RAV4     34346.20            0.03
# ...       ...          ...         ...       ...          ...             ...
# 4992     4993           10  2024-11-26    Tundra     47497.87            0.02
# 4993     4994            4  2024-11-07     Camry     26498.13            0.05
# 4995     4996            1  2024-11-06   Corolla     21484.83            0.05
# 4997     4998           18  2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10  2024-11-21   Corolla     22654.59             NaN
#
# ...

# %%
sales_with_commission = (
    toyota_sales_data[toyota_sales_data["sale_status"] == "Completed"]
    .assign(commission_earned=lambda x : round(x["sale_amount"] * x["commission_pct"],2))
)

# %%
sales_with_commission = (
    pd.merge(sales_reps_data, toyota_sales_data, left_on="rep_id", right_on="sale_rep_id", how="inner")
    .query("sale_status == 'Completed'")
    .assign(commission_earned = lambda x : round(x["sale_amount"] * x["commission_pct"]))


)

# %%
sales_with_commission
# Out:
#       rep_id first_name last_name                     email  phone_number  \
# 0          1    Anthony     Davis  anthony.davis@toyota.com         -5390
# 1          1    Anthony     Davis  anthony.davis@toyota.com         -5390
# 2          1    Anthony     Davis  anthony.davis@toyota.com         -5390
# 3          1    Anthony     Davis  anthony.davis@toyota.com         -5390
# 4          1    Anthony     Davis  anthony.davis@toyota.com         -5390
# ...      ...        ...       ...                       ...           ...
# 4995      20     Edward     Jones   edward.jones@toyota.com         -4686
# 4996      20     Edward     Jones   edward.jones@toyota.com         -4686
# 4997      20     Edward     Jones   edward.jones@toyota.com         -4686
# 4998      20     Edward     Jones   edward.jones@toyota.com         -4686
# 4999      20     Edward     Jones   edward.jones@toyota.com         -4686
#
#      hire_date region    status  sale_id  sale_rep_id   sale_date   car_model  \
# ...
