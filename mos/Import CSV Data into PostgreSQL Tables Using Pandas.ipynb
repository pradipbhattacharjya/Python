# %%
import pandas as pd

# %%
sales_reps_df = pd.read_csv('sales_reps_data.csv')

# %%
sales_reps_df.head()
# Out:
#    rep_id first_name last_name                     email  phone_number  \
# 0       1    Anthony     Davis  anthony.davis@toyota.com         -5390
# 1       2     Edward     Smith   edward.smith@toyota.com        -10708
# 2       3       Paul     Jones     paul.jones@toyota.com         -2301
# 3       4     Robert     Lopez   robert.lopez@toyota.com         -8631
# 4       5     Steven    Wilson  steven.wilson@toyota.com         -6958
#
#   hire_date region  status
# 0   7/21/22  North  Active
# 1  12/24/19  North  Active
# 2    9/6/22   East  Active
# 3  11/21/20  South  Active
# 4   3/17/22   West  Active

# %%
sales_reps_df.shape
# Out:
# (22, 8)

# %%
help(sales_reps_df.to_sql)
# Out:
# Help on method to_sql in module pandas.core.generic:
#
# to_sql(
#     name: 'str',
#     con,
#     *,
#     schema: 'str | None' = None,
#     if_exists: "Literal['fail', 'replace', 'append']" = 'fail',
#     index: 'bool_t' = True,
#     index_label: 'IndexLabel | None' = None,
#     chunksize: 'int | None' = None,
#     dtype: 'DtypeArg | None' = None,
#     method: "Literal['multi'] | Callable | None" = None
# ) -> 'int | None' method of pandas.core.frame.DataFrame instance
#     Write records stored in a DataFrame to a SQL database.
#
#     Databases supported by SQLAlchemy [1]_ are supported. Tables can be
#     newly created, appended to, or overwritten.
#
#     Parameters
#     ----------
#     name : str
#         Name of SQL table.
#     con : sqlalchemy.engine.(Engine or Connection) or sqlite3.Connection
#         Using SQLAlchemy makes it possible to use any DB supported by that
#         library. Legacy support is provided for sqlite3.Connection objects. The user
# ...

# %%
sales_reps_df.to_sql(
    'sales_reps_table',
    'postgres+pg8000://car_sales_user:itversity@localhost/car_sales_user',
    if_exists='append',

)

# %%
sales_reps_df.dtypes
# Out:
# rep_id           int64
# first_name      object
# last_name       object
# email           object
# phone_number     int64
# hire_date       object
# region          object
# status          object
# dtype: object

# %%
sales_reps_df['hire_date'] =pd.to_datetime(sales_reps_df['hire_date'],format='%d/%m/%Y').dt.date
sales_reps_df.head()
