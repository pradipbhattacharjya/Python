# %%
#Create a set
my_set = {1, 2, 3, 4, 5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
my_empty_set = set()
print(type(my_empty_set))
# Out:
# <class 'set'>

# %%
my_empty_set = set([1,2,3,4,5,6])
print(my_empty_set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_empty_set = set([1,2,3,6,5,4,5,6])
print(my_empty_set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
##
