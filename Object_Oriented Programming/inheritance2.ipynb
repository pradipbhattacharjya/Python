# %%
class Car:
    def __init__(self,window,doors,enginetype):
        self.window = window
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print(f"The person will drive  the {self.enginetype} car ")

# %%
car1 = Car(4,4,"petrol")
car1.drive()
# Out:
# The person will drive  the petrol car

# %%
class Tesla(Car):
    def __init__(self,window,doors,enginetype,is_selfdriving):
        super().__init__(window,doors,enginetype)
        self.is_selfdriving = is_selfdriving

    def selfdriving(self):
        print(f"The person will drive  the {self.is_selfdriving} ")

# %%
tesla1 = Tesla(4,5,"electric",True)

print(tesla1.window)
tesla1.selfdriving()
# Out:
# 4
# The person will drive  the True

# %%
## Multiple Inheritance
## When a class inherits from more than one base class.
## Base class 1

class Animal:
    def __init__(self,name):
            self.name = name

    def speak(self):
        print("Subclass must implement this method")

## Base class 2
class pet:
    def __init__(self,owner):
        self.owner = owner
        
## Derived class
class Dog(Animal,pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        pet.__init__(self,owner)
        

    def speak(self):
        return f"{self.name} says woof!"
    
## Create an object
dog = Dog("Buddy","Alice")
print(dog.speak())
print(f"{dog.name} is owned by {dog.owner}")
# Out:
# Buddy says woof!
# Buddy is owned by Alice
